# %%
import numpy as np
import matplotlib.pyplot as plt
img = np.zeros((1080, 1920, 3), dtype = 'uint16')
img[:360,:,0:1]=255
img[360:720, :, :]=255
img[360:720, 780:1140, :]=0
img[720:, :, 1]=200
plt.imshow(img)
plt.show()

# %%
plt.imshow(img[360:720, 780:1140, :])
plt.show()

# %%
img[360:720, 780:1140, :]=plt.imread('Ashoka_chakra.jpg')
plt.imshow(img[360:720, 780:1140, :])
plt.show()

# %%
img[360:720, 780:1140, :]=plt.imread('Ashoka_chakra.jpg')
plt.imshow(img)
